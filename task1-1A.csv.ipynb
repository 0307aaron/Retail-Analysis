# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('data1.csv')
df2 = pd.read_csv('data2.csv')
data = pd.merge(df1, df2, on = '商品')
np.unique(data.设备ID)
# Out:
# array(['E43A6E078A04134', 'E43A6E078A04172', 'E43A6E078A04228',
#        'E43A6E078A06874', 'E43A6E078A07631'], dtype=object)

# %%
Eq34 = data[data.设备ID == 'E43A6E078A04134']
Eq34
# Out:
#                                   订单号             设备ID  应付金额  实际金额  \
# 12      DD201708167493020259455996247  E43A6E078A04134   9.0   9.0
# 13     DD2017081674930318307402396486  E43A6E078A04134   4.5   4.5
# 24      DD201708167493122702085385253  E43A6E078A04134   4.5   4.5
# 26      DD201708167493142208525870814  E43A6E078A04134   4.5   4.5
# 29      DD201708167493170708641339583  E43A6E078A04134   4.5   4.5
# ...                               ...              ...   ...   ...
# 70658    DD20170816749392436530101498  E43A6E078A04134  15.0  15.0
# 70660   DD201708167493925969232724077  E43A6E078A04134  15.0  15.0
# 70664   DD201708167493825692633555502  E43A6E078A04134   5.0   5.0
# 70665    DD20170816749361738997439148  E43A6E078A04134   5.0   5.0
# 70673   DD201708167493773559548628425  E43A6E078A04134   5.0   5.0
#
#                   商品              支付时间 地点      状态   提现   大类     二级类
# 12      68g好丽友巧克力派2枚   2017/4/17 10:21  B  已出货未退款  已提现  非饮料    饼干糕点
# 13      68g好丽友巧克力派2枚   2017/4/20 23:11  B  已出货未退款  已提现  非饮料    饼干糕点
# 24      68g好丽友巧克力派2枚   2017/5/20 11:57  B  已出货未退款  已提现  非饮料    饼干糕点
# 26      68g好丽友巧克力派2枚   2017/5/23 21:39  B  已出货未退款  已提现  非饮料    饼干糕点
# 29      68g好丽友巧克力派2枚   2017/5/28 17:34  B  已出货未退款  已提现  非饮料    饼干糕点
# ...              ...               ... ..     ...  ...  ...     ...
# 70658          利群（硬）   2017/9/10 19:28  B  已出货未退款  已提现  非饮料      香烟
# 70660          利群（硬）  2017/12/11 22:43  B  已出货未退款  已提现  非饮料      香烟
# 70664  220g宝丰龙龟苓膏菊花味   2017/12/7 12:05  B  已出货未退款  已提现  非饮料  果冻/龟苓膏
# 70665   200g喜之郎/什锦果肉   2017/9/15 14:56  B  已出货未退款  已提现  非饮料  果冻/龟苓膏
# 70673      90g顺宝九制杨梅   2017/11/1 12:33  B  已出货未退款  已提现  非饮料   蜜饯/果干
#
# [13482 rows x 11 columns]

# %%
Eq34.订单号.value_counts()
# Out:
# 订单号
# DD201708167493020259455996247    1
# DD2017052818022021157AD2F2196    1
# DD2017081600183570E1EB7751EAC    1
# DD2017062921215132446AFB290B2    1
# DD20170728182240923E8B60B1578    1
#                                 ..
# DD201708167493836430044037702    1
# DD201708167493528856164490307    1
# DD20170816749387672908701877     1
# DD2017081016005760A75384AE967    1
# DD201708167493773559548628425    1
# Name: count, Length: 13482, dtype: int64

# %%
csv_file_path = 'task1-1A.csv'
Eq34.to_csv(csv_file_path, index=False)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to task1-1A.csv
