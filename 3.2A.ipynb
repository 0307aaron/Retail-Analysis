# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties

# %%
A = pd.read_csv('3.2Adata.csv')
A.sample(5)
# Out:
#                                  订单号             设备ID  应付金额  实际金额  \
# 8975   DD20170727142833677989C25545C  E43A6E078A04134   1.0   1.0
# 3443   DD20170529211406734E7597484A4  E43A6E078A04134   3.5   3.5
# 5337   DD201708167493688460615094188  E43A6E078A04134   5.5   5.5
# 5711   DD201708181602533045023E5A4B5  E43A6E078A04134   3.0   3.0
# 10427  DD20170810191022920207DE57B16  E43A6E078A04134   4.0   4.0
#
#                  商品                 支付时间 地点      状态   提现   大类   二级类  Year  \
# 8975            小鱼仔  2017-12-01 09:41:00  B  已出货未退款  已提现  非饮料  海味零食  2017
# 3443          统一冰红茶  2017-12-03 22:20:00  B  已出货未退款  已提现   饮料   茶饮料  2017
# 5337   500ml统一阿萨姆奶茶  2017-07-24 15:57:00  B  已出货未退款  已提现   饮料   茶饮料  2017
# 5711          怡宝纯净水  2017-01-10 11:52:00  B  已出货未退款  已提现   饮料     水  2017
# 10427           熊字饼  2017-01-23 16:20:00  B  已出货未退款  已提现  非饮料  饼干糕点  2017
#
#        Month  Day  Hrs  Min
# 8975      12    1    9   41
# 3443      12    3   22   20
# 5337       7   24   15   57
# 5711       1   10   11   52
# 10427      1   23   16   20

# %%
data = A[A.大类 == '饮料']

# %%
beverage_counts = data['二级类'].value_counts()
font_path = '/System/Library/Fonts/PingFang.ttc'
font_prop = FontProperties(fname=font_path)
colors = sns.color_palette('bright')[0:10]
plt.figure(figsize=(10, 7))
plt.pie(beverage_counts, labels=beverage_counts.index, colors=colors, autopct='%.0f%%', textprops={'fontproperties': font_prop})
plt.title('饮料类商品销售比例', fontproperties=font_prop)
plt.show()

# %%
df = data.groupby(['商品']).agg({'实际金额':'sum','二级类':'first'}).reset_index()

# %%
sorted_df = df.groupby('二级类').apply(lambda x: x.sort_values('实际金额', ascending=False).head(5)).reset_index(drop=True)
sorted_df
# Out:
#                        商品    实际金额   二级类
# 0                    营养快线  1830.0   乳制品
# 1              100g*5瓶益力多   733.0   乳制品
# 2          330ml伊利畅意乳酸菌原味   632.0   乳制品
# 3             250ml燕塘原味酸奶   622.5   乳制品
# 4             145ml旺仔牛奶盒装   614.0   乳制品
# 5                     商品1     0.2    其他
# 6                     商品2     0.2    其他
# 7                    商品14     0.1    其他
# 8                      脉动  1872.0  功能饮料
# 9                    东鹏特饮  1715.0  功能饮料
# 10                     红牛  1201.5  功能饮料
# 11                250ml红牛   817.5  功能饮料
# 12              600ml脉动青柠   188.5  功能饮料
# 13          268ml雀巢咖啡丝滑拿铁   662.5    咖啡
# 14                   雀巢咖啡   225.0    咖啡
# 15            180ml雀巢咖啡罐装   162.0    咖啡
# 16           13g雀巢咖啡1+2特浓    15.0    咖啡
# 17               拿铁咖啡（统一）     5.5    咖啡
# 18                  银鹭八宝粥   480.0  方便速食
# 19                    果粒橙   900.0  果蔬饮料
# 20            450ml美汁源果粒橙   387.0  果蔬饮料
# 21                   冰糖雪梨   202.5  果蔬饮料
# 22  500ml农夫果园 (芒果+菠萝+番石榴)   124.5  果蔬饮料
# 23                 美汁源果粒橙    64.0  果蔬饮料
# 24            250ml维他原味豆奶   732.6  植物蛋白
# 25           250ml维他奶巧克力味   305.1  植物蛋白
# 26                    维他奶   263.0  植物蛋白
# 27                  椰树牌椰汁    76.5  植物蛋白
# 28           250ml维他奶低糖原味    66.0  植物蛋白
# 29                  怡宝纯净水  3478.5     水
# 30                     怡宝   113.0     水
# 31                 康师傅矿泉水    21.1     水
# 32                  雪力矿泉水    14.0     水
# 33                  怡宝矿泉水     6.0     水
# 34              可口可乐330ml   622.5  碳酸饮料
# 35                芬达330ml   612.5  碳酸饮料
# 36              雪碧（500ml）   468.5  碳酸饮料
# 37                  雪碧最新款   428.0  碳酸饮料
# 38                可口可乐最新款   345.5  碳酸饮料
# 39                  阿萨姆奶茶  1931.0   茶饮料
# 40             王老吉（500ml）  1379.5   茶饮料
# 41                  统一冰红茶  1116.5   茶饮料
# 42             250ml维他柠檬茶   827.0   茶饮料
# 43                 王老吉（罐）   756.5   茶饮料

# %%
order_df = pd.read_csv('3-1A.csv')
order_df.head(5)
# Out:
#       商品  订单数量   二级类  标签
# 0  怡宝纯净水  1342     水  畅销
# 1   东鹏特饮   488  功能饮料  畅销
# 2  阿萨姆奶茶   457   茶饮料  畅销
# 3     脉动   431  功能饮料  畅销
# 4   营养快线   425   乳制品  畅销

# %%
tag_df = sorted_df.merge(order_df)

# %%
tag_df = tag_df[tag_df.标签 != '滞销'].reset_index(drop = True)

# %% [markdown]
# 通过pie chart我们可以知道每个饮料类型的销售占比，因此对于销量占比高的（茶饮料，乳制品，水等）我们应该做好充足的库存。除此之外，我找出了销量最好的饮料，因此对于这些饮料，我们要确保他们不会断货同时也要做好即使补货的准备特别是对于有着畅销销量的饮料，这样我们的收益才会更高。同时，我们也可以探究这些饮料销量好的原因，是否是因为顾客喜欢这些饮料如果是的话，我们可以多售卖这些饮料，或者是否是因为外部因素（比如说搞活动）导致了这些饮料的销量更高，如果是这个原因我们可以通过AB testing来判断是否这些活动是真实有效的，进而我们可以推广到其他商品上去。对于那些销量不好的饮料，我们可以考虑是否是因为商品的味道的问题，然后可以考虑是否要换掉这些饮料来提高我们的收益和减少没必要的inventory cost。基于这个点，我们可以采访一下购买的用户看一下他们的想法，同时也可以询问下他们是否有我们没cover到的饮料（换句话来说就是看看所有的饮料是否有cover到大部分的受众群体）

# %%
path = '3.2A.csv'
tag_df.to_csv(path,index = False)
