# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties

# %%
D = pd.read_csv('3.2Ddata.csv')
D.sample(5)
# Out:
#                                  订单号             设备ID  应付金额  实际金额  \
# 20037  DD2017070502420022013979C545D  E43A6E078A06874   3.5   3.5
# 5143    DD20170816749397599865081377  E43A6E078A06874   6.0   6.0
# 19128  DD20170709100152665A7BFC5D034  E43A6E078A06874   3.5   3.5
# 181    DD201708167493920685391474701  E43A6E078A06874   1.5   1.5
# 21819  DD20170620121344272F7B81092B9  E43A6E078A06874   1.5   1.5
#
#                 商品                 支付时间 地点      状态   提现   大类       二级类  Year  \
# 20037  可口可乐（500ml）  2017-11-15 15:51:00  E  已出货未退款  已提现   饮料      碳酸饮料  2017
# 5143            红牛  2017-12-14 18:40:00  E  已出货未退款  已提现   饮料      功能饮料  2017
# 19128         冰糖雪梨  2017-11-19 11:05:00  E  已出货未退款  已提现   饮料      果蔬饮料  2017
# 181     40g双汇玉米热狗肠  2017-06-18 21:31:00  E  已出货未退款  已提现  非饮料  肉干/豆制品/蛋  2017
# 21819       好吃点小饼干  2017-11-06 18:44:00  E  已出货未退款  已提现  非饮料      饼干糕点  2017
#
#        Month  Day  Hrs  Min
# 20037     11   15   15   51
# 5143      12   14   18   40
# 19128     11   19   11    5
# 181        6   18   21   31
# 21819     11    6   18   44

# %%
data = D[D.大类 == '饮料']

# %%
beverage_counts = data['二级类'].value_counts()
font_path = '/System/Library/Fonts/PingFang.ttc'
font_prop = FontProperties(fname=font_path)
colors = sns.color_palette('bright')[0:10]
plt.figure(figsize=(10, 7))
plt.pie(beverage_counts, labels=beverage_counts.index, colors=colors, autopct='%.0f%%', textprops={'fontproperties': font_prop})
plt.title('饮料类商品销售比例', fontproperties=font_prop)
plt.show()

# %%
df = data.groupby(['商品']).agg({'实际金额':'sum','二级类':'first'}).reset_index()

# %%
sorted_df = df.groupby('二级类').apply(lambda x: x.sort_values('实际金额', ascending=False).head(5)).reset_index(drop=True)
sorted_df
# Out:
#                        商品    实际金额   二级类
# 0                    营养快线  3532.5   乳制品
# 1             250ml燕塘原味酸奶  1132.0   乳制品
# 2              250ml燕塘甜牛奶  1021.0   乳制品
# 3                   伊利优酸乳  1019.0   乳制品
# 4             250ml燕塘红枣牛奶   957.5   乳制品
# 5                     商品1     0.3    其他
# 6                     商品2     0.1    其他
# 7                      脉动  4510.5  功能饮料
# 8                    东鹏特饮  2615.0  功能饮料
# 9                      红牛  1954.5  功能饮料
# 10                250ml红牛  1476.4  功能饮料
# 11              600ml脉动青柠   603.8  功能饮料
# 12          268ml雀巢咖啡丝滑拿铁  1291.0    咖啡
# 13                   雀巢咖啡   732.0    咖啡
# 14            180ml雀巢咖啡罐装   121.5    咖啡
# 15               拿铁咖啡（统一）    43.5    咖啡
# 16           13g雀巢咖啡1+2特浓    12.5    咖啡
# 17                  银鹭八宝粥   919.0  方便速食
# 18                    果粒橙  1743.0  果蔬饮料
# 19            450ml美汁源果粒橙   559.5  果蔬饮料
# 20                   冰糖雪梨   508.5  果蔬饮料
# 21  500ml农夫果园 (芒果+菠萝+番石榴)   299.5  果蔬饮料
# 22                    芦荟汁   259.0  果蔬饮料
# 23            250ml维他原味豆奶  1296.0  植物蛋白
# 24           250ml维他奶巧克力味   438.8  植物蛋白
# 25                    维他奶   400.5  植物蛋白
# 26                 维他原味豆奶   367.5  植物蛋白
# 27                  椰树牌椰汁   250.5  植物蛋白
# 28                  怡宝纯净水  4619.5     水
# 29                     怡宝    80.0     水
# 30                 康师傅矿泉水    75.9     水
# 31                  雪力矿泉水    70.0     水
# 32                  怡宝矿泉水    38.0     水
# 33                芬达330ml  1233.0  碳酸饮料
# 34                  雪碧最新款   990.5  碳酸饮料
# 35              可口可乐330ml   762.0  碳酸饮料
# 36            可口可乐（500ml）   740.0  碳酸饮料
# 37              雪碧（500ml）   628.6  碳酸饮料
# 38                  阿萨姆奶茶  3485.5   茶饮料
# 39                  统一冰红茶  2174.5   茶饮料
# 40             王老吉（500ml）  1880.0   茶饮料
# 41                   统一绿茶  1716.0   茶饮料
# 42                 王老吉（罐）  1579.0   茶饮料

# %%
order_df = pd.read_csv('3-1D.csv')
order_df.head(5)
# Out:
#       商品  订单数量   二级类  标签
# 0  怡宝纯净水  1705     水  畅销
# 1     脉动   996  功能饮料  畅销
# 2   营养快线   805   乳制品  畅销
# 3  阿萨姆奶茶   792   茶饮料  畅销
# 4   东鹏特饮   709  功能饮料  畅销

# %%
tag_df = sorted_df.merge(order_df)
tag_df = tag_df[tag_df.标签 != '滞销'].reset_index(drop = True)

# %% [markdown]
# 通过pie chart我们可以知道每个饮料类型的销售占比，因此对于销量占比高的（茶饮料，乳制品，水等）我们应该做好充足的库存。除此之外，我找出了销量最好的饮料，因此对于这些饮料，我们要确保他们不会断货同时也要做好即使补货的准备特别是对于有着畅销销量的饮料，这样我们的收益才会更高。同时，我们也可以探究这些饮料销量好的原因，是否是因为顾客喜欢这些饮料如果是的话，我们可以多售卖这些饮料，或者是否是因为外部因素（比如说搞活动）导致了这些饮料的销量更高，如果是这个原因我们可以通过AB testing来判断是否这些活动是真实有效的，进而我们可以推广到其他商品上去。对于那些销量不好的饮料，我们可以考虑是否是因为商品的味道的问题，然后可以考虑是否要换掉这些饮料来提高我们的收益和减少没必要的inventory cost。基于这个点，我们可以采访一下购买的用户看一下他们的想法，同时也可以询问下他们是否有我们没cover到的饮料（换句话来说就是看看所有的饮料是否有cover到大部分的受众群体）

# %%
path = '3.2D.csv'
tag_df.to_csv(path,index = False)
