# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('data1.csv')
df2 = pd.read_csv('data2.csv')
data = pd.merge(df1, df2, on = '商品')
np.unique(data.设备ID)
# Out:
# array(['E43A6E078A04134', 'E43A6E078A04172', 'E43A6E078A04228',
#        'E43A6E078A06874', 'E43A6E078A07631'], dtype=object)

# %%
Eq72 = data[data.设备ID == 'E43A6E078A04172']
Eq72
# Out:
#                                  订单号             设备ID  应付金额  实际金额  \
# 19     DD201708167493091719979004996  E43A6E078A04172   4.0   4.0
# 23     DD201708167493759152443537589  E43A6E078A04172   4.5   4.5
# 45      DD20170816749329468754945629  E43A6E078A04172   4.0   4.0
# 48     DD201708167493327069170546001  E43A6E078A04172   4.5   4.5
# 58     DD201708167493329868074871668  E43A6E078A04172   4.5   4.5
# ...                              ...              ...   ...   ...
# 70663  DD201708167493576088944838253  E43A6E078A04172   5.0   5.0
# 70670  DD201708167493435737847961442  E43A6E078A04172   2.0   2.0
# 70672  DD201708167493584820073836344  E43A6E078A04172   6.0   6.0
# 70674  DD201708167493577208345166776  E43A6E078A04172   5.5   5.5
# 70677  DD201708167493774605081730209  E43A6E078A04172  11.0  11.0
#
#                    商品              支付时间 地点      状态   提现   大类       二级类
# 19       68g好丽友巧克力派2枚   2017/5/10 20:15  A  已出货未退款  已提现  非饮料      饼干糕点
# 23       68g好丽友巧克力派2枚   2017/5/16 19:08  A  已出货未退款  已提现  非饮料      饼干糕点
# 45       68g好丽友巧克力派2枚   2017/6/16 14:24  A  已出货未退款  已提现  非饮料      饼干糕点
# 48       68g好丽友巧克力派2枚   2017/6/21 13:38  A  已出货未退款  已提现  非饮料      饼干糕点
# 58       68g好丽友巧克力派2枚   2017/6/21 22:24  A  已出货未退款  已提现  非饮料      饼干糕点
# ...               ...               ... ..     ...  ...  ...       ...
# 70663   220g宝丰龙龟苓膏菊花味   2017/10/22 7:43  A  已出货未退款  已提现  非饮料    果冻/龟苓膏
# 70670  越南LIPO奶味面包干10g   2017/10/8 16:24  A  已出货未退款  已提现  非饮料      饼干糕点
# 70672    60g湖湘贡手撕鸭脖原味  2017/10/23 14:17  A  已出货未退款  已提现  非饮料  肉干/豆制品/蛋
# 70674       20g洽洽每日坚果   2017/11/1 22:36  A  已出货未退款  已提现  非饮料      坚果炒货
# 70677      80g粤光宝盒芒果干    2017/12/4 6:47  A  已出货未退款  已提现  非饮料     蜜饯/果干
#
# [10486 rows x 11 columns]

# %%
Eq72.订单号.value_counts()
# Out:
# 订单号
# DD201708167493091719979004996    1
# DD20170816749355281293497129     1
# DD201708167493422426934519535    1
# DD201708167493426147638980575    1
# DD201708167493428773222771296    1
#                                 ..
# DD2017081674932678358856314      1
# DD201708167493269919559090713    1
# DD201708167493271218846577856    1
# DD201708167493278809310864796    1
# DD201708167493774605081730209    1
# Name: count, Length: 10486, dtype: int64

# %%
csv_file_path = 'task1-1B.csv'
Eq72.to_csv(csv_file_path, index=False)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to task1-1B.csv
